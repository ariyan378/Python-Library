# %%
import pandas as pd

# %%
Country = pd.read_csv(r"countries of the world.csv")

# %%
Country
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
Csv = pd.read_csv("sales_data_sample.csv")

# %%
print(Csv)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("SampleSuperstore.xlsx")

# %%
print(df)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
json = pd.read_json(r"sample_Data.json")

# %%
print(json)
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
import pandas as pd

data = {
    "Name" :['Ariyan' , 'Rimi' ,' Himu'],
    "Age"  : [22,23,16],
    "City" :['Dhaka' , 'Mirpur', 'Pallabi'] 
}

df = pd.DataFrame(data)
print(df)

#df.to_csv("Output.csv" , index= False) #data to csv convert
df.to_excel("Output.xlsx" , index= False) #data to csv convert
# Out:
#      Name  Age     City
# 0  Ariyan   22    Dhaka
# 1    Rimi   23   Mirpur
# 2    Himu   16  Pallabi

# %%
#understand the data set\
#find missing data
#plan next steppp

# %%
#head [n] , tail[n]  n = number
import pandas as pd

df= pd.read_json("sample_Data.json")

print(df.head(10))
print(df.tail(10))
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
# 5   6                    Fitbit Versa 3 Smartwatch
# 6   7                       KitchenAid Stand Mixer
# 7   8           Dyson V11 Absolute Cordless Vacuum
# 8   9                   Ninja Foodi Smart XL Grill
# 9  10              Canon EOS Rebel T8i DSLR Camera
#
#                                          description    price  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00
# ...

# %% [markdown]
# #column ,row
# #what type of data we have
# #missing data
#
# #info method (give us summary of data)
#
# 1. it will give us number of row and number of column
# 2. column name
# 3. return us data type
# 4.non null counts
# 5. memeory usage of data frame

# %%
import pandas as pd

df= pd.read_json("sample_Data.json")


print("Display the info of data set")

print(df.info())

print(df.describe())
# Out:
# Display the info of data set
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     object
#  2   description  20 non-null     object
#  3   price        20 non-null     float64
#  4   category     20 non-null     object
#  5   image        20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB
# None
#              id        price
# count  20.00000    20.000000
# mean   10.50000   507.687000
# std     5.91608   373.008199
# min     1.00000   129.950000
# 25%     5.75000   244.237500
# 50%    10.50000   374.990000
# 75%    15.25000   724.742500
# max    20.00000  1599.990000

# %%
#describe

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

print("Descriptive statistics")
print(Df.describe())

'''Count: There are 7 data points for each variable.
Mean: The average
Min: The youngest individual is 10 years old,
the lowest salary is $50,000, and the lowest performance score 
is 60.25% (1st Quartile): 25% of the individuals are 20 years or younger, earn $63,500 or less, and have a performance score of 70 or lower..'''
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# Descriptive statistics
#              Age         salary  performance
# count   8.000000       8.000000     8.000000
# mean   22.000000  159625.000000    78.750000
# std     5.830952  129144.368275    11.877349
# min    10.000000   50000.000000    60.000000
# 25%    20.000000   65250.000000    72.500000
# 50%    23.000000  100000.000000    80.000000
# 75%    25.000000  225000.000000    86.250000
# max    30.000000  400000.000000    95.000000
# ...

# %% [markdown]
# 1. How big is your data set
# 2.what are the name of the column

# %%
#shape and size 

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

print(f'Shape:,{Df.shape}')
print(f'Column Name:,{Df.columns}')
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# Shape:,(8, 4)
# Column Name:,Index(['Name', 'Age', 'salary', 'performance'], dtype='object')

# %%
#select specific column
#filter rows
#combine multiple condition

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

print(Df.info())
print(Df.describe())

print("Name (single column return series)")

name = Df["Name"]
print(name)

#selecting multiple column
select = Df[["Age" , "salary" ] ]

print(select)

#filtering row
print("Filtering row")
high_salary = Df[(Df['salary'] > 100000) | (Df['Age'] < 20)]

print(high_salary)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8 non-null      object
#  1   Age          8 non-null      int64
#  2   salary       8 non-null      int64
#  3   performance  8 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 388.0+ bytes
# None
#              Age         salary  performance
# count   8.000000       8.000000     8.000000
# mean   22.000000  159625.000000    78.750000
# std     5.830952  129144.368275    11.877349
# ...

# %%
#add column and row 
#remove 

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)


#adding new column
#Df["new column name"]
print("Adding new column")
Df["Bonus"] = Df['salary'] * 0.1
print(Df)


#insert method better because we can any where by using this
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# Adding new column
#       Name  Age  salary  performance    Bonus
# 0     Himu   10  200000           80  20000.0
# 1   hridoy   20  300000           85  30000.0
# 2   ariyan   25  400000           90  40000.0
# 3    islam   30  100000           95  10000.0
# 4     Rimi   20   50000           60   5000.0
# 5    Afifa   24   60000           65   6000.0
# 6  analyst   22   67000           75   6700.0
# 7      Nub   25  100000           80  10000.0

# %%
#using in[]
#df.insert(loc , "Column name" , some-data)


import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)


Df.insert(0 , "Employee Id " , [1,2,3,4,5,6,7,8])

print(Df)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
#    Employee Id      Name  Age  salary  performance
# 0             1     Himu   10  200000           80
# 1             2   hridoy   20  300000           85
# 2             3   ariyan   25  400000           90
# 3             4    islam   30  100000           95
# 4             5     Rimi   20   50000           60
# 5             6    Afifa   24   60000           65
# 6             7  analyst   22   67000           75
# 7             8      Nub   25  100000           80

# %%
#updating Values

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)


#.loc[] specfic data acess 
#df.loc[row_index , "column name "] = new data

Df.loc[0,'salary'] = 300000
print(Df)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
#       Name  Age  salary  performance
# 0     Himu   10  300000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80

# %%
#increasing multiple value

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

Df['salary'] = Df['salary'] * 1.10

print(Df)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
#       Name  Age    salary  performance
# 0     Himu   10  220000.0           80
# 1   hridoy   20  330000.0           85
# 2   ariyan   25  440000.0           90
# 3    islam   30  110000.0           95
# 4     Rimi   20   55000.0           60
# 5    Afifa   24   66000.0           65
# 6  analyst   22   73700.0           75
# 7      Nub   25  110000.0           80

# %%
#Removing column , Row
#Drop method
#df.drop(column = ["culumn name" , inplace = true])

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

Df.drop(columns= ["performance"] , inplace= True)
print(Df)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
#       Name  Age  salary
# 0     Himu   10  200000
# 1   hridoy   20  300000
# 2   ariyan   25  400000
# 3    islam   30  100000
# 4     Rimi   20   50000
# 5    Afifa   24   60000
# 6  analyst   22   67000
# 7      Nub   25  100000

# %%
#Handling missing data

#NaN( not a number)
#Noen(for object type number )

# we will use isnull() method
#true - nan is missing 
#false - value is present 
#sum() give us the sum of value missing

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , None,'Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,None,20,24,22,25],
    "salary" : [200000,300000,400000,None,50000,60000,67000,100000],
    "performance" : [80,85,90,None,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)


print(Df.isnull().sum())

#dropna(Inplace = true)

#removes missing values

Df.dropna(inplace= True)
print(Df)

#fillna(value , inplace = True)
# Out:
#       Name   Age    salary  performance
# 0     Himu  10.0  200000.0         80.0
# 1   hridoy  20.0  300000.0         85.0
# 2   ariyan  25.0  400000.0         90.0
# 3     None   NaN       NaN          NaN
# 4     Rimi  20.0   50000.0         60.0
# 5    Afifa  24.0   60000.0         65.0
# 6  analyst  22.0   67000.0         75.0
# 7      Nub  25.0  100000.0         80.0
# Name           1
# Age            1
# salary         1
# performance    1
# dtype: int64
#       Name   Age    salary  performance
# 0     Himu  10.0  200000.0         80.0
# 1   hridoy  20.0  300000.0         85.0
# 2   ariyan  25.0  400000.0         90.0
# 4     Rimi  20.0   50000.0         60.0
# 5    Afifa  24.0   60000.0         65.0
# 6  analyst  22.0   67000.0         75.0
# 7      Nub  25.0  100000.0         80.0

# %%
#inter pollution

#we can a estimated value in our missing value
#predict the misssing value and filter
#smotth trends
#avoid data logs

#interpolate method

# %%
import pandas as pd

#linear , polynomial , time

data = {
    "Name" : ['Himu','hridoy','ariyan' , None,'Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,None,20,24,22,25],
    "salary" : [200000,300000,400000,None,50000,60000,67000,100000],
    "performance" : [80,85,90,None,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

Df.interpolate(method= "linear" , axis = 0 , inplace=True)
print(Df)
# Out:
#       Name   Age    salary  performance
# 0     Himu  10.0  200000.0         80.0
# 1   hridoy  20.0  300000.0         85.0
# 2   ariyan  25.0  400000.0         90.0
# 3     None   NaN       NaN          NaN
# 4     Rimi  20.0   50000.0         60.0
# 5    Afifa  24.0   60000.0         65.0
# 6  analyst  22.0   67000.0         75.0
# 7      Nub  25.0  100000.0         80.0
#       Name   Age    salary  performance
# 0     Himu  10.0  200000.0         80.0
# 1   hridoy  20.0  300000.0         85.0
# 2   ariyan  25.0  400000.0         90.0
# 3     None  22.5  225000.0         75.0
# 4     Rimi  20.0   50000.0         60.0
# 5    Afifa  24.0   60000.0         65.0
# 6  analyst  22.0   67000.0         75.0
# 7      Nub  25.0  100000.0         80.0
# C:\Users\PL\AppData\Local\Temp\ipykernel_13852\1859664766.py:15: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
# ...

# %%
#sorting and aggregession
#df.sort_values(by = "column name" , True/False , inplace =true)

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)



Df.sort_values(by = ["Age" , "salary"], ascending = [True , False], inplace= True)
print(Df)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 4     Rimi   20   50000           60
# 6  analyst   22   67000           75
# 5    Afifa   24   60000           65
# 2   ariyan   25  400000           90
# 7      Nub   25  100000           80
# 3    islam   30  100000           95

# %%
#aggregession

#df.["column Name "].mean()
#df.["column Name "].sum()
#df.["column Name "].min()
#df.["column Name "].max()


import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

avg_salary = Df["salary"].mean()

print("AVG")

print(avg_salary)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# AVG
# 159625.0

# %%
#Grouping salary
#group by

import pandas as pd

data = {
    "Name" : ['Himu','hridoy','ariyan' , 'islam','Rimi', 'Afifa', 'analyst','Nub'] , 
    "Age"  : [10,20,25,30,20,24,22,25],
    "salary" : [200000,300000,400000,100000,50000,60000,67000,100000],
    "performance" : [80,85,90,95,60,65,75,80]
}

Df = pd.DataFrame(data)
print(Df)

grouped = Df.groupby("Age")["salary"].sum()

print(grouped)
# Out:
#       Name  Age  salary  performance
# 0     Himu   10  200000           80
# 1   hridoy   20  300000           85
# 2   ariyan   25  400000           90
# 3    islam   30  100000           95
# 4     Rimi   20   50000           60
# 5    Afifa   24   60000           65
# 6  analyst   22   67000           75
# 7      Nub   25  100000           80
# Age
# 10    200000
# 20    350000
# 22     67000
# 24     60000
# 25    500000
# 30    100000
# Name: salary, dtype: int64

# %%
#merging and joning 
import pandas as pd

# Sample DataFrames
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Score': [85, 90, 78]
})

df2 = pd.DataFrame({
    'ID': [3, 1, 2],
    'Subject': ['Math', 'Science', 'English']
})

import pandas as pd

# Sample DataFrames
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Score': [85, 90, 78]
})

df2 = pd.DataFrame({
    'ID': [3, 1, 2],
    'Subject': ['Math', 'Science', 'English']
})

# Merge DataFrames on 'ID'
merged_df = pd.merge(df1, df2, on='ID', how = "inner")
print(merged_df)
# Out:
#    ID     Name  Score  Subject
# 0   1    Alice     85  Science
# 1   2      Bob     90  English
# 2   3  Charlie     78     Math

# %%
#concate
import pandas as pd

# Sample DataFrames
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Score': [85, 90, 78]
})

df2 = pd.DataFrame({
    'ID': [4, 5, 6],
    'Name': ['David', 'Eve', 'Frank'],
    'Score': [88, 92, 80]
})

# Concatenate DataFrames
concated_df = pd.concat([df1, df2], ignore_index=True)

# Sort by 'Score' in descending order
sorted_df = concated_df.sort_values(by='Score', ascending=False)

print(sorted_df)
# Out:
#    ID     Name  Score
# 4   5      Eve     92
# 1   2      Bob     90
# 3   4    David     88
# 0   1    Alice     85
# 5   6    Frank     80
# 2   3  Charlie     78
